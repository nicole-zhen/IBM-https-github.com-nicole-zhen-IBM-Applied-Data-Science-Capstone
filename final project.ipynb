# %%
#import all libraries
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

# %%
#download data
source = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
soup = BeautifulSoup(source,'lxml')

# %%
table_can = soup.find('table')
cells = table_can.find_all('td')

postcode = []
borough = []
neighbourhood = []

for i in range(0, len(cells), 3):
    postcode.append(cells[i].text.strip())
    borough.append(cells[i+1].text.strip())
    neighbourhood.append(cells[i+2].text.strip())

# %%
#transpose the data into dataframe
df_pc = pd.DataFrame(data=[postcode, borough, neighbourhood]).transpose()
df_pc.columns = ['Postcode', 'Borough', 'Neighbourhood']
df_pc.head(10)
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront
# 5      M5A  Downtown Toronto       Regent Park
# 6      M6A        North York  Lawrence Heights
# 7      M6A        North York    Lawrence Manor
# 8      M7A      Queen's Park      Not assigned
# 9      M8A      Not assigned      Not assigned

# %%
#remove the boroughs with empty data
#If a cell has a borough but a Not assigned neighborhood, then the neighborhood will be the same as the borough.
df_pc.drop(df_pc[df_pc['Borough'] == 'Not assigned'].index, inplace=True)
df_pc.loc[df_pc.Neighbourhood == "Not assigned", "Neighbourhood"] = df_pc.Borough

# %%
#combine neighborhoods with same postcodes
df_pc = df_pc.groupby(['Postcode', 'Borough'])['Neighbourhood'].apply(', '.join).reset_index()
df_pc.columns = ['Postcode', 'Borough', 'Neighbourhood']

# %%
df_pc.head()
# Out:
#   Postcode      Borough                           Neighbourhood
# 0      M1B  Scarborough                          Rouge, Malvern
# 1      M1C  Scarborough  Highland Creek, Rouge Hill, Port Union
# 2      M1E  Scarborough       Guildwood, Morningside, West Hill
# 3      M1G  Scarborough                                  Woburn
# 4      M1H  Scarborough                               Cedarbrae

# %%
#import geographical data csv file
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share your notebook.
client_8c6994d0c2af4c0e899abe707846c03e = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='Q_MZD0YEV8OjvU36XNXXef4twtJX3Kf8ANbD4VWhNZj9',
    ibm_auth_endpoint="https://iam.bluemix.net/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

body = client_8c6994d0c2af4c0e899abe707846c03e.get_object(Bucket='finalproject-donotdelete-pr-sovuftm1o0rpex',Key='Geospatial_Coordinates.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_1 = pd.read_csv(body)
df_data_1.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
#comebine two datasets together to get a new dataset contains both postcode and geographical information
Combined_data = df_pc.join(df_data_1)
Combined_data.head()
# Out:
#   Postcode      Borough                           Neighbourhood Postal Code  \
# 0      M1B  Scarborough                          Rouge, Malvern         M1B
# 1      M1C  Scarborough  Highland Creek, Rouge Hill, Port Union         M1C
# 2      M1E  Scarborough       Guildwood, Morningside, West Hill         M1E
# 3      M1G  Scarborough                                  Woburn         M1G
# 4      M1H  Scarborough                               Cedarbrae         M1H
#
#     Latitude  Longitude
# 0  43.806686 -79.194353
# 1  43.784535 -79.160497
# 2  43.763573 -79.188711
# 3  43.770992 -79.216917
# 4  43.773136 -79.239476

# %%
import json # library to handle JSON files
from geopy.geocoders import Nominatim
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
import matplotlib.cm as cm
import matplotlib.colors as colors
# import k-means from clustering stage
from sklearn.cluster import KMeans
import xml

# %%
#account information for Foursqaure
CLIENT_ID = 'WWK0OPNLKLO4NYAXIJTHSVUZM2Y5MODZP43EZLKC5M2DHA2V' # your Foursquare ID
CLIENT_SECRET = 'HTAFAKDEZXZNNZ4KWS13C1OD5JBZYXLM5A1TLPXNG0GHXDBX' # your Foursquare Secret
VERSION = '20190511' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: WWK0OPNLKLO4NYAXIJTHSVUZM2Y5MODZP43EZLKC5M2DHA2V
# CLIENT_SECRET:HTAFAKDEZXZNNZ4KWS13C1OD5JBZYXLM5A1TLPXNG0GHXDBX

# %%
#create a new dataset contains all neighborhoods in North York
df_ny = Combined_data[Combined_data['Borough'].str.contains('North York')]

df_ny.reset_index(drop=True, inplace = True)
df_ny.head(10)
# Out:
#   Postcode     Borough                 Neighbourhood Postal Code   Latitude  \
# 0      M2H  North York             Hillcrest Village         M2H  43.803762
# 1      M2J  North York  Fairview, Henry Farm, Oriole         M2J  43.778517
# 2      M2K  North York               Bayview Village         M2K  43.786947
# 3      M2L  North York      Silver Hills, York Mills         M2L  43.757490
# 4      M2M  North York       Newtonbrook, Willowdale         M2M  43.789053
# 5      M2N  North York              Willowdale South         M2N  43.770120
# 6      M2P  North York               York Mills West         M2P  43.752758
# 7      M2R  North York               Willowdale West         M2R  43.782736
# 8      M3A  North York                     Parkwoods         M3A  43.753259
# 9      M3B  North York               Don Mills North         M3B  43.745906
#
#    Longitude
# 0 -79.363452
# 1 -79.346556
# 2 -79.385975
# 3 -79.374714
# 4 -79.408493
# 5 -79.408493
# 6 -79.400049
# 7 -79.442259
# 8 -79.329656
# 9 -79.352188

# %%
#import folium
# !pip install folium
# Out:
# Collecting folium
#   Downloading https://files.pythonhosted.org/packages/43/77/0287320dc4fd86ae8847bab6c34b5ec370e836a79c7b0c16680a3d9fd770/folium-0.8.3-py2.py3-none-any.whl (87kB)
#     100% |████████████████████████████████| 92kB 7.0MB/s eta 0:00:01
# Requirement not upgraded as not directly required: six in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from folium)
# Requirement not upgraded as not directly required: jinja2 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from folium)
# Requirement not upgraded as not directly required: requests in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from folium)
# Requirement not upgraded as not directly required: numpy in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from folium)
# Collecting branca>=0.3.0 (from folium)
#   Downloading https://files.pythonhosted.org/packages/63/36/1c93318e9653f4e414a2e0c3b98fc898b4970e939afeedeee6075dd3b703/branca-0.3.1-py3-none-any.whl
# Requirement not upgraded as not directly required: MarkupSafe>=0.23 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from jinja2->folium)
# Requirement not upgraded as not directly required: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests->folium)
# Requirement not upgraded as not directly required: idna<2.7,>=2.5 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests->folium)
# Requirement not upgraded as not directly required: urllib3<1.23,>=1.21.1 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests->folium)
# Requirement not upgraded as not directly required: certifi>=2017.4.17 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests->folium)
# Installing collected packages: branca, folium
# Successfully installed branca-0.3.1 folium-0.8.3

# %%
import folium

# %%
#use geolocater to add markers and create the map
address = 'North York, Canada'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

# %%
# create map of Toronto using latitude and longitude values
map_neighbour = folium.Map(location=[latitude, longitude], zoom_start=11)

# %%
# add markers to map
for lat, lng, borough, neighbourhood in zip(df_ny['Latitude'], df_ny['Longitude'], df_ny['Borough'], df_ny['Neighbourhood']):
    label = '{}, {}'.format(neighbourhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=3,
        popup=label,
        color='green',
        fill=True,
        fill_color='#3199cc',
        fill_opacity=0.3,
        parse_html=False).add_to(map_neighbour)  
    
map_neighbour
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#create a function to get venue information according to geographical information
def foursquare_crawler (postal_code_list, neighborhood_list, lat_list, lng_list, LIMIT = 500, radius = 1000):
    result_ds = []
    counter = 0
    for postal_code, neighborhood, lat, lng in zip(postal_code_list, neighborhood_list, lat_list, lng_list):
         
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, CLIENT_SECRET, VERSION, 
            lat, lng, radius, LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        tmp_dict = {}
        tmp_dict['Postal Code'] = postal_code; tmp_dict['Neighborhood(s)'] = neighborhood; 
        tmp_dict['Latitude'] = lat; tmp_dict['Longitude'] = lng;
        tmp_dict['Crawling_result'] = results;
        result_ds.append(tmp_dict)
        counter += 1
        print('{}.'.format(counter))
        print('Data is Obtained, for the Postal Code {} (and Neighborhoods {}) SUCCESSFULLY.'.format(postal_code, neighborhood))
    return result_ds;

# %%
#create a dataset contain all venue information in each neighborhoods in North York
print('Crawling different neighborhoods inside "North York"')
NY_foursquare_dataset = foursquare_crawler(list(df_ny['Postcode']),
                                                   list(df_ny['Neighbourhood']),
                                                   list(df_ny['Latitude']),
                                                   list(df_ny['Longitude']),)
# Out:
# Crawling different neighborhoods inside "North York"
# 1.
# Data is Obtained, for the Postal Code M2H (and Neighborhoods Hillcrest Village) SUCCESSFULLY.
# 2.
# Data is Obtained, for the Postal Code M2J (and Neighborhoods Fairview, Henry Farm, Oriole) SUCCESSFULLY.
# 3.
# Data is Obtained, for the Postal Code M2K (and Neighborhoods Bayview Village) SUCCESSFULLY.
# 4.
# Data is Obtained, for the Postal Code M2L (and Neighborhoods Silver Hills, York Mills) SUCCESSFULLY.
# 5.
# Data is Obtained, for the Postal Code M2M (and Neighborhoods Newtonbrook, Willowdale) SUCCESSFULLY.
# 6.
# Data is Obtained, for the Postal Code M2N (and Neighborhoods Willowdale South) SUCCESSFULLY.
# 7.
# Data is Obtained, for the Postal Code M2P (and Neighborhoods York Mills West) SUCCESSFULLY.
# 8.
# Data is Obtained, for the Postal Code M2R (and Neighborhoods Willowdale West) SUCCESSFULLY.
# 9.
# Data is Obtained, for the Postal Code M3A (and Neighborhoods Parkwoods) SUCCESSFULLY.
# 10.
# Data is Obtained, for the Postal Code M3B (and Neighborhoods Don Mills North) SUCCESSFULLY.
# 11.
# Data is Obtained, for the Postal Code M3C (and Neighborhoods Flemingdon Park, Don Mills South) SUCCESSFULLY.
# 12.
# Data is Obtained, for the Postal Code M3H (and Neighborhoods Bathurst Manor, Downsview North, Wilson Heights) SUCCESSFULLY.
# 13.
# Data is Obtained, for the Postal Code M3J (and Neighborhoods Northwood Park, York University) SUCCESSFULLY.
# 14.
# Data is Obtained, for the Postal Code M3K (and Neighborhoods CFB Toronto, Downsview East) SUCCESSFULLY.
# 15.
# Data is Obtained, for the Postal Code M3L (and Neighborhoods Downsview West) SUCCESSFULLY.
# 16.
# Data is Obtained, for the Postal Code M3M (and Neighborhoods Downsview Central) SUCCESSFULLY.
# 17.
# Data is Obtained, for the Postal Code M3N (and Neighborhoods Downsview Northwest) SUCCESSFULLY.
# 18.
# Data is Obtained, for the Postal Code M4A (and Neighborhoods Victoria Village) SUCCESSFULLY.
# 19.
# Data is Obtained, for the Postal Code M5M (and Neighborhoods Bedford Park, Lawrence Manor East) SUCCESSFULLY.
# 20.
# Data is Obtained, for the Postal Code M6A (and Neighborhoods Lawrence Heights, Lawrence Manor) SUCCESSFULLY.
# 21.
# Data is Obtained, for the Postal Code M6B (and Neighborhoods Glencairn) SUCCESSFULLY.
# 22.
# Data is Obtained, for the Postal Code M6L (and Neighborhoods Downsview, North Park, Upwood Park) SUCCESSFULLY.
# 23.
# Data is Obtained, for the Postal Code M9L (and Neighborhoods Humber Summit) SUCCESSFULLY.
# 24.
# Data is Obtained, for the Postal Code M9M (and Neighborhoods Emery, Humberlea) SUCCESSFULLY.

# %%
#define a function to get important venue information based on Foursqaure database

def get_venue_dataset(foursquare_dataset):
    result_df = pd.DataFrame(columns = ['Postal Code', 'Neighborhood', 
                                           'Neighborhood Latitude', 'Neighborhood Longitude',
                                          'Venue', 'Venue Summary', 'Venue Category', 'Distance'])
    
    for neigh_dict in foursquare_dataset:
        postal_code = neigh_dict['Postal Code']; neigh = neigh_dict['Neighborhood(s)']
        lat = neigh_dict['Latitude']; lng = neigh_dict['Longitude']
        print('Number of Venuse in Coordination "{}" Posal Code and "{}" Negihborhood(s) is:'.format(postal_code, neigh))
        print(len(neigh_dict['Crawling_result']))
        
        for venue_dict in neigh_dict['Crawling_result']:
            summary = venue_dict['reasons']['items'][0]['summary']
            name = venue_dict['venue']['name']
            dist = venue_dict['venue']['location']['distance']
            cat =  venue_dict['venue']['categories'][0]['name']
            
            
            result_df = result_df.append({'Postal Code': postal_code, 'Neighborhood': neigh, 
                              'Neighborhood Latitude': lat, 'Neighborhood Longitude':lng,
                              'Venue': name, 'Venue Summary': summary, 
                              'Venue Category': cat, 'Distance': dist}, ignore_index = True)
    
    return(result_df)

# %%
ny_venues = get_venue_dataset(NY_foursquare_dataset)
# Out:
# Number of Venuse in Coordination "M2H" Posal Code and "Hillcrest Village" Negihborhood(s) is:
# 22
# Number of Venuse in Coordination "M2J" Posal Code and "Fairview, Henry Farm, Oriole" Negihborhood(s) is:
# 44
# Number of Venuse in Coordination "M2K" Posal Code and "Bayview Village" Negihborhood(s) is:
# 13
# Number of Venuse in Coordination "M2L" Posal Code and "Silver Hills, York Mills" Negihborhood(s) is:
# 4
# Number of Venuse in Coordination "M2M" Posal Code and "Newtonbrook, Willowdale" Negihborhood(s) is:
# 30
# Number of Venuse in Coordination "M2N" Posal Code and "Willowdale South" Negihborhood(s) is:
# 100
# Number of Venuse in Coordination "M2P" Posal Code and "York Mills West" Negihborhood(s) is:
# 15
# Number of Venuse in Coordination "M2R" Posal Code and "Willowdale West" Negihborhood(s) is:
# 10
# Number of Venuse in Coordination "M3A" Posal Code and "Parkwoods" Negihborhood(s) is:
# 28
# Number of Venuse in Coordination "M3B" Posal Code and "Don Mills North" Negihborhood(s) is:
# 29
# Number of Venuse in Coordination "M3C" Posal Code and "Flemingdon Park, Don Mills South" Negihborhood(s) is:
# 44
# Number of Venuse in Coordination "M3H" Posal Code and "Bathurst Manor, Downsview North, Wilson Heights" Negihborhood(s) is:
# 28
# Number of Venuse in Coordination "M3J" Posal Code and "Northwood Park, York University" Negihborhood(s) is:
# 23
# Number of Venuse in Coordination "M3K" Posal Code and "CFB Toronto, Downsview East" Negihborhood(s) is:
# 21
# Number of Venuse in Coordination "M3L" Posal Code and "Downsview West" Negihborhood(s) is:
# 9
# Number of Venuse in Coordination "M3M" Posal Code and "Downsview Central" Negihborhood(s) is:
# 4
# Number of Venuse in Coordination "M3N" Posal Code and "Downsview Northwest" Negihborhood(s) is:
# 31
# Number of Venuse in Coordination "M4A" Posal Code and "Victoria Village" Negihborhood(s) is:
# 14
# Number of Venuse in Coordination "M5M" Posal Code and "Bedford Park, Lawrence Manor East" Negihborhood(s) is:
# 38
# Number of Venuse in Coordination "M6A" Posal Code and "Lawrence Heights, Lawrence Manor" Negihborhood(s) is:
# 51
# Number of Venuse in Coordination "M6B" Posal Code and "Glencairn" Negihborhood(s) is:
# 28
# Number of Venuse in Coordination "M6L" Posal Code and "Downsview, North Park, Upwood Park" Negihborhood(s) is:
# 12
# Number of Venuse in Coordination "M9L" Posal Code and "Humber Summit" Negihborhood(s) is:
# 10
# Number of Venuse in Coordination "M9M" Posal Code and "Emery, Humberlea" Negihborhood(s) is:
# 8

# %%
print(ny_venues.shape)
ny_venues.head()
# Out:
# (616, 8)
#   Postal Code       Neighborhood  Neighborhood Latitude  \
# 0         M2H  Hillcrest Village              43.803762
# 1         M2H  Hillcrest Village              43.803762
# 2         M2H  Hillcrest Village              43.803762
# 3         M2H  Hillcrest Village              43.803762
# 4         M2H  Hillcrest Village              43.803762
#
#    Neighborhood Longitude                                         Venue  \
# 0              -79.363452  고려삼계탕 Korean Ginseng Chicken Soup & Bibimbap
# 1              -79.363452                                        Tastee
# 2              -79.363452                                        Galati
# 3              -79.363452                                   Cummer Park
# 4              -79.363452                                   Tim Hortons
#
#           Venue Summary     Venue Category Distance
# 0  This spot is popular  Korean Restaurant      754
# 1  This spot is popular             Bakery      692
# 2  This spot is popular      Grocery Store      815
# 3  This spot is popular               Park      776
# 4  This spot is popular        Coffee Shop      731

# %%
#to get all unique data in venue category
ny_venues['Venue Category'].unique()
# Out:
# array(['Korean Restaurant', 'Bakery', 'Grocery Store', 'Park',
#        'Coffee Shop', 'Pizza Place', 'Bank', 'Sandwich Place',
#        'Fast Food Restaurant', 'Pharmacy', 'Housing Development',
#        'Chinese Restaurant', 'Ice Cream Shop', 'Shopping Mall',
#        'Recreation Center', 'Pool',
#        'Residential Building (Apartment / Condo)', 'Diner',
#        'Convenience Store', 'Toy / Game Store', 'Burger Joint',
#        'Movie Theater', 'Electronics Store', 'American Restaurant',
#        'Tea Room', 'Salon / Barbershop', 'Department Store', 'Candy Store',
#        'Smoothie Shop', 'Clothing Store', 'Japanese Restaurant',
#        'Juice Bar', 'Caribbean Restaurant', 'Food Court', 'Theater',
#        'Restaurant', 'Sporting Goods Shop', 'Video Game Store',
#        'Cosmetics Shop', 'Supermarket', 'Beer Store',
#        'Fried Chicken Joint', 'Café', 'Skating Rink', 'Skate Park',
#        'Intersection', 'Asian Restaurant', 'Hookah Bar', 'Dessert Shop',
#        'Middle Eastern Restaurant', 'Hot Dog Joint', 'Indian Restaurant',
#        'Ramen Restaurant', 'Trail', 'Gym', 'Train Station', 'Steakhouse',
#        'Seafood Restaurant', 'Hotel', 'Indonesian Restaurant', 'Creperie',
#        'Sushi Restaurant', 'Burrito Place', 'Plaza', 'Bubble Tea Shop',
#        'Sports Bar', 'Pet Store', 'Arts & Crafts Store', 'Lounge',
#        'Comfort Food Restaurant', 'Vietnamese Restaurant', 'Yoga Studio',
#        'Bar', 'Discount Store', 'Karaoke Bar', 'Pub', 'Beach',
#        'Italian Restaurant', 'Frozen Yogurt Shop', 'French Restaurant',
#        'Dog Run', 'Golf Course', 'Business Service', 'Playground',
#        'Butcher', 'Eastern European Restaurant', 'Bus Line',
#        'Fish & Chips Shop', 'Food & Drink Shop', 'Road', 'Bus Stop',
#        'Laundry Service', 'Tennis Court', 'Shop & Service',
#        'Gym / Fitness Center', 'Salad Place', 'Thai Restaurant',
#        'Breakfast Spot', 'Greek Restaurant',
#        'Paper / Office Supplies Store', 'Cafeteria', 'Mobile Phone Shop',
#        'Athletics & Sports', 'Liquor Store', 'History Museum',
#        'General Entertainment', 'Bike Shop', "Women's Store",
#        'Dim Sum Restaurant', 'Deli / Bodega', 'Office', 'Bridal Shop',
#        'Mediterranean Restaurant', 'Ski Chalet', 'Video Store',
#        'Community Center', 'Ski Area', "Men's Store", 'Massage Studio',
#        'Furniture / Home Store', 'Falafel Restaurant', 'Airport',
#        'Turkish Restaurant', 'Latin American Restaurant', 'Soccer Field',
#        'Other Repair Shop', 'Moving Target', 'Spa', 'Baseball Field',
#        'Kitchen Supply Store', 'Snack Place', 'Hockey Arena',
#        'Portuguese Restaurant', 'Bagel Shop', 'Wings Joint', 'Sports Club',
#        'Baby Store', 'Boutique', 'Bowling Alley', 'Accessories Store',
#        'Cheese Shop', 'Event Space', 'Miscellaneous Shop', 'Gift Shop',
#        'Fireworks Store', 'Cocktail Bar', 'Hardware Store', 'Fish Market',
#        'Rental Car Location', 'Shoe Store', 'Photography Lab',
#        'Empanada Restaurant', 'Storage Facility'], dtype=object)

# %%
#define all venue categories relate to restaurants
ny_re=ny_venues.loc[ny_venues['Venue Category'].isin(['Korean Restaurant', 
       'Pizza Place', 'Sandwich Place', 'Fast Food Restaurant', 'Chinese Restaurant', 
       'Burger Joint', 'American Restaurant','Tea Room', 
       'Smoothie Shop', 'Japanese Restaurant',
       'Caribbean Restaurant', 'Food Court', 'Restaurant', 
       'Fried Chicken Joint', 'Café', 'Asian Restaurant', 'Hookah Bar', 
       'Middle Eastern Restaurant', 'Hot Dog Joint', 'Indian Restaurant',
       'Ramen Restaurant', 'Steakhouse',
       'Seafood Restaurant', 'Indonesian Restaurant', 'Creperie',
       'Sushi Restaurant', 'Burrito Place','Sports Bar',
       'Comfort Food Restaurant', 'Vietnamese Restaurant', 'Bar', 'Pub', 
       'Italian Restaurant', 'French Restaurant', 'Eastern European Restaurant', 
       'Fish & Chips Shop', 'Food & Drink Shop', 'Salad Place', 'Thai Restaurant',
       'Breakfast Spot', 'Greek Restaurant', 'Cafeteria', 'Dim Sum Restaurant', 
       'Mediterranean Restaurant', 'Ski Chalet', 'Video Store','Falafel Restaurant', 
       'Turkish Restaurant', 'Latin American Restaurant', 'Snack Place', 
       'Portuguese Restaurant', 'Wings Joint', 'Cocktail Bar', 'Empanada Restaurant'])]

# %%
ny_re.head()
# Out:
#    Postal Code       Neighborhood  Neighborhood Latitude  \
# 0          M2H  Hillcrest Village              43.803762
# 5          M2H  Hillcrest Village              43.803762
# 7          M2H  Hillcrest Village              43.803762
# 8          M2H  Hillcrest Village              43.803762
# 11         M2H  Hillcrest Village              43.803762
#
#     Neighborhood Longitude                                         Venue  \
# 0               -79.363452  고려삼계탕 Korean Ginseng Chicken Soup & Bibimbap
# 5               -79.363452                                   Pizza Pizza
# 7               -79.363452                                        Subway
# 8               -79.363452                                New York Fries
# 11              -79.363452                           New Greattime Corp.
#
#            Venue Summary        Venue Category Distance
# 0   This spot is popular     Korean Restaurant      754
# 5   This spot is popular           Pizza Place      709
# 7   This spot is popular        Sandwich Place      711
# 8   This spot is popular  Fast Food Restaurant       38
# 11  This spot is popular    Chinese Restaurant      676

# %%
# one hot encoding
ny_onehot = pd.get_dummies(ny_re[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
ny_onehot['Neighborhood'] = ny_re['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [ny_onehot.columns[-1]] + list(ny_onehot.columns[:-1])
ny_onehot = ny_onehot[fixed_columns]

ny_onehot.head()
# Out:
#          Neighborhood  American Restaurant  Asian Restaurant  Bar  \
# 0   Hillcrest Village                    0                 0    0
# 5   Hillcrest Village                    0                 0    0
# 7   Hillcrest Village                    0                 0    0
# 8   Hillcrest Village                    0                 0    0
# 11  Hillcrest Village                    0                 0    0
#
#     Breakfast Spot  Burger Joint  Burrito Place  Cafeteria  Café  \
# 0                0             0              0          0     0
# 5                0             0              0          0     0
# 7                0             0              0          0     0
# 8                0             0              0          0     0
# 11               0             0              0          0     0
#
#     Caribbean Restaurant     ...       Snack Place  Sports Bar  Steakhouse  \
# 0                      0     ...                 0           0           0
# 5                      0     ...                 0           0           0
# 7                      0     ...                 0           0           0
# 8                      0     ...                 0           0           0
# 11                     0     ...                 0           0           0
#
#     Sushi Restaurant  Tea Room  Thai Restaurant  Turkish Restaurant  \
# 0                  0         0                0                   0
# 5                  0         0                0                   0
# 7                  0         0                0                   0
# 8                  0         0                0                   0
# 11                 0         0                0                   0
#
#     Video Store  Vietnamese Restaurant  Wings Joint
# 0             0                      0            0
# 5             0                      0            0
# 7             0                      0            0
# 8             0                      0            0
# 11            0                      0            0
#
# [5 rows x 55 columns]

# %%
ny_grouped = ny_onehot.groupby('Neighborhood').mean().reset_index()
ny_grouped
# Out:
#                                        Neighborhood  American Restaurant  \
# 0   Bathurst Manor, Downsview North, Wilson Heights             0.000000
# 1                                   Bayview Village             0.000000
# 2                 Bedford Park, Lawrence Manor East             0.050000
# 3                       CFB Toronto, Downsview East             0.000000
# 4                                   Don Mills North             0.000000
# 5                                 Downsview Central             0.000000
# 6                               Downsview Northwest             0.083333
# 7                                    Downsview West             0.000000
# 8                Downsview, North Park, Upwood Park             0.000000
# 9                      Fairview, Henry Farm, Oriole             0.062500
# 10                 Flemingdon Park, Don Mills South             0.105263
# 11                                        Glencairn             0.000000
# 12                                Hillcrest Village             0.000000
# 13                                    Humber Summit             0.000000
# 14                 Lawrence Heights, Lawrence Manor             0.000000
# 15                          Newtonbrook, Willowdale             0.000000
# 16                  Northwood Park, York University             0.000000
# 17                                        Parkwoods             0.000000
# 18                                 Victoria Village             0.000000
# 19                                 Willowdale South             0.017241
# 20                                  Willowdale West             0.000000
# 21                                  York Mills West             0.000000
#
#     Asian Restaurant       Bar  Breakfast Spot  Burger Joint  Burrito Place  \
# 0           0.000000  0.000000        0.000000      0.000000       0.000000
# 1           0.000000  0.000000        0.000000      0.000000       0.000000
# 2           0.000000  0.000000        0.050000      0.000000       0.000000
# 3           0.000000  0.000000        0.000000      0.000000       0.000000
# 4           0.058824  0.058824        0.058824      0.117647       0.000000
# 5           0.000000  0.000000        0.000000      0.000000       0.000000
# 6           0.000000  0.000000        0.000000      0.000000       0.000000
# 7           0.000000  0.000000        0.000000      0.000000       0.000000
# 8           0.000000  0.000000        0.000000      0.000000       0.000000
# 9           0.000000  0.000000        0.000000      0.062500       0.000000
# 10          0.105263  0.052632        0.000000      0.052632       0.000000
# 11          0.000000  0.000000        0.000000      0.000000       0.000000
# 12          0.000000  0.000000        0.000000      0.000000       0.000000
# 13          0.000000  0.000000        0.000000      0.000000       0.000000
# 14          0.000000  0.000000        0.000000      0.062500       0.000000
# 15          0.052632  0.000000        0.000000      0.000000       0.000000
# 16          0.000000  0.066667        0.000000      0.000000       0.000000
# 17          0.000000  0.000000        0.000000      0.000000       0.000000
# 18          0.000000  0.000000        0.000000      0.000000       0.000000
# 19          0.000000  0.017241        0.000000      0.000000       0.017241
# 20          0.000000  0.000000        0.000000      0.000000       0.000000
# 21          0.000000  0.000000        0.000000      0.000000       0.000000
#
#     Cafeteria      Café  Caribbean Restaurant     ...       Snack Place  \
# 0    0.000000  0.000000              0.000000     ...          0.000000
# 1    0.000000  0.200000              0.000000     ...          0.000000
# 2    0.000000  0.050000              0.000000     ...          0.000000
# 3    0.000000  0.111111              0.000000     ...          0.000000
# 4    0.058824  0.058824              0.058824     ...          0.000000
# 5    0.000000  0.000000              0.000000     ...          0.000000
# 6    0.000000  0.000000              0.083333     ...          0.083333
# 7    0.000000  0.000000              0.000000     ...          0.000000
# 8    0.000000  0.000000              0.000000     ...          0.000000
# 9    0.000000  0.000000              0.062500     ...          0.000000
# 10   0.000000  0.052632              0.000000     ...          0.000000
# 11   0.000000  0.000000              0.000000     ...          0.000000
# 12   0.000000  0.000000              0.000000     ...          0.000000
# 13   0.000000  0.000000              0.000000     ...          0.000000
# 14   0.000000  0.000000              0.000000     ...          0.000000
# 15   0.000000  0.157895              0.000000     ...          0.000000
# 16   0.000000  0.000000              0.000000     ...          0.000000
# 17   0.000000  0.142857              0.142857     ...          0.000000
# 18   0.000000  0.333333              0.000000     ...          0.000000
# 19   0.000000  0.051724              0.000000     ...          0.000000
# 20   0.000000  0.000000              0.000000     ...          0.000000
# 21   0.000000  0.000000              0.000000     ...          0.000000
#
#     Sports Bar  Steakhouse  Sushi Restaurant  Tea Room  Thai Restaurant  \
# 0     0.000000    0.000000          0.100000    0.0000         0.000000
# 1     0.000000    0.000000          0.000000    0.0000         0.000000
# 2     0.000000    0.000000          0.050000    0.0000         0.050000
# 3     0.000000    0.000000          0.000000    0.0000         0.000000
# 4     0.000000    0.000000          0.000000    0.0000         0.058824
# 5     0.000000    0.000000          0.000000    0.0000         0.000000
# 6     0.000000    0.000000          0.000000    0.0000         0.000000
# 7     0.000000    0.000000          0.000000    0.0000         0.000000
# 8     0.000000    0.000000          0.000000    0.0000         0.000000
# 9     0.000000    0.000000          0.000000    0.0625         0.000000
# 10    0.000000    0.000000          0.052632    0.0000         0.000000
# 11    0.000000    0.000000          0.000000    0.0000         0.000000
# 12    0.000000    0.000000          0.000000    0.0000         0.000000
# 13    0.000000    0.000000          0.000000    0.0000         0.000000
# 14    0.000000    0.000000          0.062500    0.0000         0.000000
# 15    0.000000    0.000000          0.000000    0.0000         0.000000
# 16    0.066667    0.000000          0.000000    0.0000         0.000000
# 17    0.000000    0.000000          0.000000    0.0000         0.000000
# 18    0.000000    0.000000          0.000000    0.0000         0.000000
# 19    0.017241    0.017241          0.068966    0.0000         0.000000
# 20    0.000000    0.000000          0.000000    0.0000         0.000000
# 21    0.000000    0.000000          0.000000    0.0000         0.000000
#
#     Turkish Restaurant  Video Store  Vietnamese Restaurant  Wings Joint
# 0             0.000000         0.10               0.000000         0.00
# 1             0.000000         0.00               0.000000         0.00
# 2             0.000000         0.05               0.000000         0.05
# 3             0.222222         0.00               0.111111         0.00
# 4             0.000000         0.00               0.000000         0.00
# 5             0.000000         0.00               0.666667         0.00
# 6             0.000000         0.00               0.083333         0.00
# 7             0.000000         0.00               0.500000         0.00
# 8             0.000000         0.00               0.000000         0.00
# 9             0.000000         0.00               0.000000         0.00
# 10            0.000000         0.00               0.000000         0.00
# 11            0.000000         0.00               0.000000         0.00
# 12            0.000000         0.00               0.000000         0.00
# 13            0.000000         0.00               0.000000         0.00
# 14            0.000000         0.00               0.125000         0.00
# 15            0.000000         0.00               0.000000         0.00
# 16            0.000000         0.00               0.000000         0.00
# 17            0.000000         0.00               0.000000         0.00
# 18            0.000000         0.00               0.000000         0.00
# 19            0.000000         0.00               0.034483         0.00
# 20            0.000000         0.00               0.000000         0.00
# 21            0.000000         0.00               0.000000         0.00
#
# [22 rows x 55 columns]

# %%
ny_onehot = pd.get_dummies(data = ny_re, drop_first  = False, 
                              prefix = "", prefix_sep = "", columns = ['Venue Category'])
ny_onehot.head()
# Out:
#    Postal Code       Neighborhood  Neighborhood Latitude  \
# 0          M2H  Hillcrest Village              43.803762
# 5          M2H  Hillcrest Village              43.803762
# 7          M2H  Hillcrest Village              43.803762
# 8          M2H  Hillcrest Village              43.803762
# 11         M2H  Hillcrest Village              43.803762
#
#     Neighborhood Longitude                                         Venue  \
# 0               -79.363452  고려삼계탕 Korean Ginseng Chicken Soup & Bibimbap
# 5               -79.363452                                   Pizza Pizza
# 7               -79.363452                                        Subway
# 8               -79.363452                                New York Fries
# 11              -79.363452                           New Greattime Corp.
#
#            Venue Summary Distance  American Restaurant  Asian Restaurant  Bar  \
# 0   This spot is popular      754                    0                 0    0
# 5   This spot is popular      709                    0                 0    0
# 7   This spot is popular      711                    0                 0    0
# 8   This spot is popular       38                    0                 0    0
# 11  This spot is popular      676                    0                 0    0
#
#        ...       Snack Place  Sports Bar  Steakhouse  Sushi Restaurant  \
# 0      ...                 0           0           0                 0
# 5      ...                 0           0           0                 0
# 7      ...                 0           0           0                 0
# 8      ...                 0           0           0                 0
# 11     ...                 0           0           0                 0
#
#     Tea Room  Thai Restaurant  Turkish Restaurant  Video Store  \
# 0          0                0                   0            0
# 5          0                0                   0            0
# 7          0                0                   0            0
# 8          0                0                   0            0
# 11         0                0                   0            0
#
#     Vietnamese Restaurant  Wings Joint
# 0                       0            0
# 5                       0            0
# 7                       0            0
# 8                       0            0
# 11                      0            0
#
# [5 rows x 61 columns]

# %%
#to sum the number of each kind of restaurants in each neighborhood
ny_onehot = ny_onehot.groupby(
    'Neighborhood').sum()

ny_onehot.head()
# Out:
#                                                  Neighborhood Latitude  \
# Neighborhood
# Bathurst Manor, Downsview North, Wilson Heights             437.543283
# Bayview Village                                             218.934737
# Bedford Park, Lawrence Manor East                           874.665650
# CFB Toronto, Downsview East                                 393.637259
# Don Mills North                                             743.680399
#
#                                                  Neighborhood Longitude  \
# Neighborhood
# Bathurst Manor, Downsview North, Wilson Heights             -794.422593
# Bayview Village                                             -396.929875
# Bedford Park, Lawrence Manor East                          -1588.394994
# CFB Toronto, Downsview East                                 -715.182870
# Don Mills North                                            -1348.987196
#
#                                                  American Restaurant  \
# Neighborhood
# Bathurst Manor, Downsview North, Wilson Heights                    0
# Bayview Village                                                    0
# Bedford Park, Lawrence Manor East                                  1
# CFB Toronto, Downsview East                                        0
# Don Mills North                                                    0
#
#                                                  Asian Restaurant  Bar  \
# Neighborhood
# Bathurst Manor, Downsview North, Wilson Heights                 0    0
# Bayview Village                                                 0    0
# Bedford Park, Lawrence Manor East                               0    0
# CFB Toronto, Downsview East                                     0    0
# Don Mills North                                                 1    1
#
#                                                  Breakfast Spot  Burger Joint  \
# Neighborhood
# Bathurst Manor, Downsview North, Wilson Heights               0             0
# Bayview Village                                               0             0
# Bedford Park, Lawrence Manor East                             1             0
# CFB Toronto, Downsview East                                   0             0
# Don Mills North                                               1             2
#
#                                                  Burrito Place  Cafeteria  \
# Neighborhood
# Bathurst Manor, Downsview North, Wilson Heights              0          0
# Bayview Village                                              0          0
# Bedford Park, Lawrence Manor East                            0          0
# CFB Toronto, Downsview East                                  0          0
# Don Mills North                                              0          1
#
#                                                  Café     ...       \
# Neighborhood                                              ...
# Bathurst Manor, Downsview North, Wilson Heights     0     ...
# Bayview Village                                     1     ...
# Bedford Park, Lawrence Manor East                   1     ...
# CFB Toronto, Downsview East                         1     ...
# Don Mills North                                     1     ...
#
#                                                  Snack Place  Sports Bar  \
# Neighborhood
# Bathurst Manor, Downsview North, Wilson Heights            0           0
# Bayview Village                                            0           0
# Bedford Park, Lawrence Manor East                          0           0
# CFB Toronto, Downsview East                                0           0
# Don Mills North                                            0           0
#
#                                                  Steakhouse  Sushi Restaurant  \
# Neighborhood
# Bathurst Manor, Downsview North, Wilson Heights           0                 1
# Bayview Village                                           0                 0
# Bedford Park, Lawrence Manor East                         0                 1
# CFB Toronto, Downsview East                               0                 0
# Don Mills North                                           0                 0
#
#                                                  Tea Room  Thai Restaurant  \
# Neighborhood
# Bathurst Manor, Downsview North, Wilson Heights         0                0
# Bayview Village                                         0                0
# Bedford Park, Lawrence Manor East                       0                1
# CFB Toronto, Downsview East                             0                0
# Don Mills North                                         0                1
#
#                                                  Turkish Restaurant  \
# Neighborhood
# Bathurst Manor, Downsview North, Wilson Heights                   0
# Bayview Village                                                   0
# Bedford Park, Lawrence Manor East                                 0
# CFB Toronto, Downsview East                                       2
# Don Mills North                                                   0
#
#                                                  Video Store  \
# Neighborhood
# Bathurst Manor, Downsview North, Wilson Heights            1
# Bayview Village                                            0
# Bedford Park, Lawrence Manor East                          1
# CFB Toronto, Downsview East                                0
# Don Mills North                                            0
#
#                                                  Vietnamese Restaurant  \
# Neighborhood
# Bathurst Manor, Downsview North, Wilson Heights                      0
# Bayview Village                                                      0
# Bedford Park, Lawrence Manor East                                    0
# CFB Toronto, Downsview East                                          1
# Don Mills North                                                      0
#
#                                                  Wings Joint
# Neighborhood
# Bathurst Manor, Downsview North, Wilson Heights            0
# Bayview Village                                            0
# Bedford Park, Lawrence Manor East                          1
# CFB Toronto, Downsview East                                0
# Don Mills North                                            0
#
# [5 rows x 56 columns]

# %%
# import k-means from clustering stage
from sklearn.cluster import KMeans

# run k-means clustering
kmeans = KMeans(n_clusters = 5, random_state = 0).fit(ny_onehot)

# %%
means_df = pd.DataFrame(kmeans.cluster_centers_)
means_df.columns = ny_onehot.columns
means_df.index = ['G1','G2','G3','G4','G5']
means_df['Total Sum'] = means_df.sum(axis = 1)
means_df.sort_values(axis = 0, by = ['Total Sum'], ascending=False)
# Out:
#     Neighborhood Latitude  Neighborhood Longitude  American Restaurant  \
# G1             170.648526             -309.730131         5.551115e-17
# G4             470.208760             -854.299582         2.500000e-01
# G3             700.038168            -1270.569307         2.500000e-01
# G5             845.816584            -1534.877965         1.000000e+00
# G2            2538.666954            -4605.692582         1.000000e+00
#
#     Asian Restaurant           Bar  Breakfast Spot  Burger Joint  \
# G1     -2.775558e-17 -2.775558e-17   -1.387779e-17  2.775558e-17
# G4      0.000000e+00  0.000000e+00    0.000000e+00  0.000000e+00
# G3      2.500000e-01  5.000000e-01    2.500000e-01  1.000000e+00
# G5      1.000000e+00  3.333333e-01    3.333333e-01  3.333333e-01
# G2      0.000000e+00  1.000000e+00    0.000000e+00  0.000000e+00
#
#     Burrito Place     Cafeteria      Café     ...         Sports Bar  \
# G1  -6.938894e-18 -6.938894e-18  0.300000     ...      -1.387779e-17
# G4   0.000000e+00  0.000000e+00  0.250000     ...       0.000000e+00
# G3   0.000000e+00  2.500000e-01  0.250000     ...       2.500000e-01
# G5   6.938894e-18  6.938894e-18  1.666667     ...       1.387779e-17
# G2   1.000000e+00  0.000000e+00  3.000000     ...       1.000000e+00
#
#       Steakhouse  Sushi Restaurant      Tea Room  Thai Restaurant  \
# G1 -6.938894e-18     -5.551115e-17 -6.938894e-18    -1.387779e-17
# G4  0.000000e+00      2.500000e-01  0.000000e+00     0.000000e+00
# G3  0.000000e+00      2.500000e-01  2.500000e-01     2.500000e-01
# G5  6.938894e-18      6.666667e-01  6.938894e-18     3.333333e-01
# G2  1.000000e+00      4.000000e+00  0.000000e+00     0.000000e+00
#
#     Turkish Restaurant   Video Store  Vietnamese Restaurant   Wings Joint  \
# G1       -1.387779e-17 -1.387779e-17                    0.3 -6.938894e-18
# G4        5.000000e-01  2.500000e-01                    0.5  0.000000e+00
# G3        0.000000e+00  0.000000e+00                    0.5  0.000000e+00
# G5        1.387779e-17  3.333333e-01                    0.0  3.333333e-01
# G2        0.000000e+00  0.000000e+00                    2.0  0.000000e+00
#
#       Total Sum
# G1  -135.181605
# G4  -373.340821
# G3  -554.531139
# G5  -669.728048
# G2 -2009.025628
#
# [5 rows x 57 columns]

# %%
#connect the cluster group with the neighborhoods
neigh_summary = pd.DataFrame([ny_onehot.index, 1 + kmeans.labels_]).T
neigh_summary.columns = ['Neighborhood', 'Group']
neigh_summary
# Out:
#                                        Neighborhood Group
# 0   Bathurst Manor, Downsview North, Wilson Heights     4
# 1                                   Bayview Village     1
# 2                 Bedford Park, Lawrence Manor East     5
# 3                       CFB Toronto, Downsview East     4
# 4                                   Don Mills North     3
# 5                                 Downsview Central     1
# 6                               Downsview Northwest     4
# 7                                    Downsview West     1
# 8                Downsview, North Park, Upwood Park     1
# 9                      Fairview, Henry Farm, Oriole     3
# 10                 Flemingdon Park, Don Mills South     5
# 11                                        Glencairn     4
# 12                                Hillcrest Village     1
# 13                                    Humber Summit     1
# 14                 Lawrence Heights, Lawrence Manor     3
# 15                          Newtonbrook, Willowdale     5
# 16                  Northwood Park, York University     3
# 17                                        Parkwoods     1
# 18                                 Victoria Village     1
# 19                                 Willowdale South     2
# 20                                  Willowdale West     1
# 21                                  York Mills West     1

# %%
#explore top 10 vnues 
num_top_venues = 10

for hood in ny_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = ny_grouped[ny_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Bathurst Manor, Downsview North, Wilson Heights----
#                        venue  freq
# 0             Sandwich Place   0.1
# 1                 Restaurant   0.1
# 2                Video Store   0.1
# 3   Mediterranean Restaurant   0.1
# 4  Middle Eastern Restaurant   0.1
# 5           Sushi Restaurant   0.1
# 6        Fried Chicken Joint   0.1
# 7                Pizza Place   0.1
# 8                 Ski Chalet   0.1
# 9       Fast Food Restaurant   0.1
#
#
# ----Bayview Village----
#                        venue  freq
# 0        Japanese Restaurant   0.4
# 1                       Café   0.2
# 2         Chinese Restaurant   0.2
# 3       Fast Food Restaurant   0.2
# 4        American Restaurant   0.0
# 5             Sandwich Place   0.0
# 6  Latin American Restaurant   0.0
# 7   Mediterranean Restaurant   0.0
# 8  Middle Eastern Restaurant   0.0
# 9                Pizza Place   0.0
#
#
# ----Bedford Park, Lawrence Manor East----
#                   venue  freq
# 0  Fast Food Restaurant  0.15
# 1    Italian Restaurant  0.15
# 2   American Restaurant  0.05
# 3           Video Store  0.05
# 4       Thai Restaurant  0.05
# 5      Sushi Restaurant  0.05
# 6        Sandwich Place  0.05
# 7            Restaurant  0.05
# 8                   Pub  0.05
# 9           Pizza Place  0.05
#
#
# ----CFB Toronto, Downsview East----
#                        venue  freq
# 0         Turkish Restaurant  0.22
# 1      Vietnamese Restaurant  0.11
# 2  Latin American Restaurant  0.11
# 3                       Café  0.11
# 4  Middle Eastern Restaurant  0.11
# 5                Pizza Place  0.11
# 6         Italian Restaurant  0.11
# 7             Sandwich Place  0.11
# 8        American Restaurant  0.00
# 9                Salad Place  0.00
#
#
# ----Don Mills North----
#                   venue  freq
# 0   Japanese Restaurant  0.18
# 1           Pizza Place  0.12
# 2          Burger Joint  0.12
# 3                   Bar  0.06
# 4        Breakfast Spot  0.06
# 5             Cafeteria  0.06
# 6                  Café  0.06
# 7  Caribbean Restaurant  0.06
# 8           Salad Place  0.06
# 9      Asian Restaurant  0.06
#
#
# ----Downsview Central----
#                        venue  freq
# 0      Vietnamese Restaurant  0.67
# 1                 Restaurant  0.33
# 2        American Restaurant  0.00
# 3             Sandwich Place  0.00
# 4        Japanese Restaurant  0.00
# 5          Korean Restaurant  0.00
# 6  Latin American Restaurant  0.00
# 7   Mediterranean Restaurant  0.00
# 8  Middle Eastern Restaurant  0.00
# 9                Pizza Place  0.00
#
#
# ----Downsview Northwest----
#                    venue  freq
# 0   Fast Food Restaurant  0.17
# 1            Pizza Place  0.17
# 2    American Restaurant  0.08
# 3         Sandwich Place  0.08
# 4            Snack Place  0.08
# 5    Fried Chicken Joint  0.08
# 6     Chinese Restaurant  0.08
# 7   Caribbean Restaurant  0.08
# 8  Vietnamese Restaurant  0.08
# 9     Falafel Restaurant  0.08
#
#
# ----Downsview West----
#                        venue  freq
# 0      Vietnamese Restaurant   0.5
# 1                Pizza Place   0.5
# 2        American Restaurant   0.0
# 3             Sandwich Place   0.0
# 4        Japanese Restaurant   0.0
# 5          Korean Restaurant   0.0
# 6  Latin American Restaurant   0.0
# 7   Mediterranean Restaurant   0.0
# 8  Middle Eastern Restaurant   0.0
# 9      Portuguese Restaurant   0.0
#
#
# ----Downsview, North Park, Upwood Park----
#                        venue  freq
# 0   Mediterranean Restaurant   0.2
# 1                Pizza Place   0.2
# 2         Chinese Restaurant   0.2
# 3         Dim Sum Restaurant   0.2
# 4             Sandwich Place   0.2
# 5        American Restaurant   0.0
# 6         Seafood Restaurant   0.0
# 7          Korean Restaurant   0.0
# 8  Latin American Restaurant   0.0
# 9  Middle Eastern Restaurant   0.0
#
#
# ----Fairview, Henry Farm, Oriole----
#                   venue  freq
# 0  Fast Food Restaurant  0.19
# 1   Japanese Restaurant  0.12
# 2        Sandwich Place  0.12
# 3         Smoothie Shop  0.06
# 4           Pizza Place  0.06
# 5   Fried Chicken Joint  0.06
# 6            Food Court  0.06
# 7            Restaurant  0.06
# 8   American Restaurant  0.06
# 9  Caribbean Restaurant  0.06
#
#
# ----Flemingdon Park, Don Mills South----
#                        venue  freq
# 0                 Restaurant  0.16
# 1        American Restaurant  0.11
# 2        Japanese Restaurant  0.11
# 3           Asian Restaurant  0.11
# 4           Sushi Restaurant  0.05
# 5         Italian Restaurant  0.05
# 6             Sandwich Place  0.05
# 7       Fast Food Restaurant  0.05
# 8         Dim Sum Restaurant  0.05
# 9  Middle Eastern Restaurant  0.05
#
#
# ----Glencairn----
#                        venue  freq
# 0       Fast Food Restaurant  0.33
# 1        Japanese Restaurant  0.08
# 2         Italian Restaurant  0.08
# 3  Latin American Restaurant  0.08
# 4   Mediterranean Restaurant  0.08
# 5           Greek Restaurant  0.08
# 6                Pizza Place  0.08
# 7                        Pub  0.08
# 8                 Restaurant  0.08
# 9          Korean Restaurant  0.00
#
#
# ----Hillcrest Village----
#                        venue  freq
# 0             Sandwich Place   0.2
# 1          Korean Restaurant   0.2
# 2                Pizza Place   0.2
# 3         Chinese Restaurant   0.2
# 4       Fast Food Restaurant   0.2
# 5        American Restaurant   0.0
# 6  Latin American Restaurant   0.0
# 7   Mediterranean Restaurant   0.0
# 8  Middle Eastern Restaurant   0.0
# 9      Portuguese Restaurant   0.0
#
#
# ----Humber Summit----
#                        venue  freq
# 0                Pizza Place  0.50
# 1        Empanada Restaurant  0.25
# 2         Italian Restaurant  0.25
# 3        American Restaurant  0.00
# 4             Sandwich Place  0.00
# 5          Korean Restaurant  0.00
# 6  Latin American Restaurant  0.00
# 7   Mediterranean Restaurant  0.00
# 8  Middle Eastern Restaurant  0.00
# 9      Portuguese Restaurant  0.00
#
#
# ----Lawrence Heights, Lawrence Manor----
#                    venue  freq
# 0   Fast Food Restaurant  0.19
# 1             Restaurant  0.12
# 2  Vietnamese Restaurant  0.12
# 3    Fried Chicken Joint  0.12
# 4         Sandwich Place  0.06
# 5     Seafood Restaurant  0.06
# 6      Korean Restaurant  0.06
# 7           Cocktail Bar  0.06
# 8       Greek Restaurant  0.06
# 9       Sushi Restaurant  0.06
#
#
# ----Newtonbrook, Willowdale----
#                        venue  freq
# 0          Korean Restaurant  0.21
# 1                       Café  0.16
# 2  Middle Eastern Restaurant  0.11
# 3                Pizza Place  0.11
# 4           Ramen Restaurant  0.05
# 5        Japanese Restaurant  0.05
# 6           Asian Restaurant  0.05
# 7          Indian Restaurant  0.05
# 8              Hot Dog Joint  0.05
# 9                 Hookah Bar  0.05
#
#
# ----Northwood Park, York University----
#                        venue  freq
# 0                Pizza Place  0.20
# 1                 Restaurant  0.20
# 2             Sandwich Place  0.13
# 3         Falafel Restaurant  0.07
# 4                 Sports Bar  0.07
# 5                        Bar  0.07
# 6        Japanese Restaurant  0.07
# 7  Middle Eastern Restaurant  0.07
# 8       Fast Food Restaurant  0.07
# 9         Chinese Restaurant  0.07
#
#
# ----Parkwoods----
#                        venue  freq
# 0       Fast Food Restaurant  0.14
# 1                Pizza Place  0.14
# 2                       Café  0.14
# 3       Caribbean Restaurant  0.14
# 4         Chinese Restaurant  0.14
# 5          Food & Drink Shop  0.14
# 6          Fish & Chips Shop  0.14
# 7        American Restaurant  0.00
# 8   Mediterranean Restaurant  0.00
# 9  Middle Eastern Restaurant  0.00
#
#
# ----Victoria Village----
#                        venue  freq
# 0                Pizza Place  0.33
# 1                       Café  0.33
# 2      Portuguese Restaurant  0.33
# 3        American Restaurant  0.00
# 4         Seafood Restaurant  0.00
# 5          Korean Restaurant  0.00
# 6  Latin American Restaurant  0.00
# 7   Mediterranean Restaurant  0.00
# 8  Middle Eastern Restaurant  0.00
# 9                        Pub  0.00
#
#
# ----Willowdale South----
#                   venue  freq
# 0      Ramen Restaurant  0.10
# 1           Pizza Place  0.09
# 2  Fast Food Restaurant  0.09
# 3   Japanese Restaurant  0.09
# 4     Korean Restaurant  0.09
# 5      Sushi Restaurant  0.07
# 6        Sandwich Place  0.07
# 7                  Café  0.05
# 8            Restaurant  0.05
# 9    Chinese Restaurant  0.03
#
#
# ----Willowdale West----
#                          venue  freq
# 0  Eastern European Restaurant   0.5
# 1                  Pizza Place   0.5
# 2          American Restaurant   0.0
# 3            Korean Restaurant   0.0
# 4    Latin American Restaurant   0.0
# 5     Mediterranean Restaurant   0.0
# 6    Middle Eastern Restaurant   0.0
# 7        Portuguese Restaurant   0.0
# 8                          Pub   0.0
# 9             Ramen Restaurant   0.0
#
#
# ----York Mills West----
#                        venue  freq
# 0                 Restaurant  0.67
# 1          French Restaurant  0.33
# 2        American Restaurant  0.00
# 3             Sandwich Place  0.00
# 4          Korean Restaurant  0.00
# 5  Latin American Restaurant  0.00
# 6   Mediterranean Restaurant  0.00
# 7  Middle Eastern Restaurant  0.00
# 8                Pizza Place  0.00
# 9      Portuguese Restaurant  0.00

# %%
#define a function to find the top 10 venues(restaurants) in each neighborhood
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = ny_grouped['Neighborhood']

for ind in np.arange(ny_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(ny_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                       Neighborhood 1st Most Common Venue  \
# 0  Bathurst Manor, Downsview North, Wilson Heights            Restaurant
# 1                                  Bayview Village   Japanese Restaurant
# 2                Bedford Park, Lawrence Manor East  Fast Food Restaurant
# 3                      CFB Toronto, Downsview East    Turkish Restaurant
# 4                                  Don Mills North   Japanese Restaurant
#
#    2nd Most Common Venue      3rd Most Common Venue 4th Most Common Venue  \
# 0   Fast Food Restaurant  Middle Eastern Restaurant   Fried Chicken Joint
# 1                   Café         Chinese Restaurant  Fast Food Restaurant
# 2     Italian Restaurant                Wings Joint        Sandwich Place
# 3  Vietnamese Restaurant         Italian Restaurant                  Café
# 4            Pizza Place               Burger Joint             Cafeteria
#
#        5th Most Common Venue        6th Most Common Venue  \
# 0   Mediterranean Restaurant               Sandwich Place
# 1                Wings Joint  Eastern European Restaurant
# 2             Breakfast Spot                         Café
# 3  Latin American Restaurant    Middle Eastern Restaurant
# 4                 Restaurant             Greek Restaurant
#
#      7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 0               Ski Chalet           Pizza Place      Sushi Restaurant
# 1         Greek Restaurant   Fried Chicken Joint     French Restaurant
# 2  Comfort Food Restaurant      Greek Restaurant           Pizza Place
# 3           Sandwich Place           Pizza Place           Wings Joint
# 4                     Café           Salad Place        Breakfast Spot
#
#         10th Most Common Venue
# 0                  Video Store
# 1                   Food Court
# 2                          Pub
# 3  Eastern European Restaurant
# 4              Thai Restaurant

# %%
df_nyre = df_ny.loc[df_ny['Neighbourhood'].isin(['Bayview Village', 'Downsview Central', 'Downsview West',
                                      'Downsview, North Park, Upwood Park', 'Hillcrest Village',
                                      'Humber Summit', 'Parkwoods', 'Victoria Village', 'Willowdale West',
                                      'York Mills West'])]

# %%
df_nyre.head()
# Out:
#   Postcode     Borough      Neighbourhood Postal Code   Latitude  Longitude
# 0      M2H  North York  Hillcrest Village         M2H  43.803762 -79.363452
# 2      M2K  North York    Bayview Village         M2K  43.786947 -79.385975
# 6      M2P  North York    York Mills West         M2P  43.752758 -79.400049
# 7      M2R  North York    Willowdale West         M2R  43.782736 -79.442259
# 8      M3A  North York          Parkwoods         M3A  43.753259 -79.329656

# %%
# create map of Toronto using latitude and longitude values
map_neighbour1 = folium.Map(location=[latitude, longitude], zoom_start=11)

# %%
# add markers to map
for lat, lng, borough, neighbourhood in zip(df_nyre['Latitude'], df_nyre['Longitude'], 
                                            df_nyre['Borough'], df_nyre['Neighbourhood']):
    label = '{}, {}'.format(neighbourhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=3,
        popup=label,
        color='green',
        fill=True,
        fill_color='#3199cc',
        fill_opacity=0.3,
        parse_html=False).add_to(map_neighbour1)  
    
map_neighbour1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#explore the neighborhoods in cluster group 1
neighborhoods_venues_sorted.loc[neighborhoods_venues_sorted['Neighborhood']=='Bayview Village']
# Out:
#       Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 1  Bayview Village   Japanese Restaurant                  Café
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 1    Chinese Restaurant  Fast Food Restaurant           Wings Joint
#
#          6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 1  Eastern European Restaurant      Greek Restaurant   Fried Chicken Joint
#
#   9th Most Common Venue 10th Most Common Venue
# 1     French Restaurant             Food Court

# %%
neighborhoods_venues_sorted.loc[neighborhoods_venues_sorted['Neighborhood']=='Downsview Central']
# Out:
#         Neighborhood  1st Most Common Venue 2nd Most Common Venue  \
# 5  Downsview Central  Vietnamese Restaurant            Restaurant
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 5         Hot Dog Joint            Hookah Bar      Greek Restaurant
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 5   Fried Chicken Joint     French Restaurant            Food Court
#
#   9th Most Common Venue 10th Most Common Venue
# 5     Food & Drink Shop      Fish & Chips Shop

# %%
neighborhoods_venues_sorted.loc[neighborhoods_venues_sorted['Neighborhood']=='Downsview West']
# Out:
#      Neighborhood  1st Most Common Venue 2nd Most Common Venue  \
# 7  Downsview West  Vietnamese Restaurant           Pizza Place
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 7         Hot Dog Joint            Hookah Bar      Greek Restaurant
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 7   Fried Chicken Joint     French Restaurant            Food Court
#
#   9th Most Common Venue 10th Most Common Venue
# 7     Food & Drink Shop      Fish & Chips Shop

# %%
neighborhoods_venues_sorted.loc[neighborhoods_venues_sorted['Neighborhood']=='Downsview, North Park, Upwood Park']
# Out:
#                          Neighborhood 1st Most Common Venue  \
# 8  Downsview, North Park, Upwood Park    Dim Sum Restaurant
#
#       2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 8  Mediterranean Restaurant           Pizza Place    Chinese Restaurant
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 8        Sandwich Place           Wings Joint   Fried Chicken Joint
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 8     French Restaurant            Food Court      Food & Drink Shop

# %%
neighborhoods_venues_sorted.loc[neighborhoods_venues_sorted['Neighborhood']=='Hillcrest Village']
# Out:
#          Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 12  Hillcrest Village     Korean Restaurant  Fast Food Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 12           Pizza Place    Chinese Restaurant        Sandwich Place
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 12           Wings Joint    Dim Sum Restaurant   Fried Chicken Joint
#
#    9th Most Common Venue 10th Most Common Venue
# 12     French Restaurant             Food Court

# %%
neighborhoods_venues_sorted.loc[neighborhoods_venues_sorted['Neighborhood']=='Humber Summit']
# Out:
#      Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 13  Humber Summit           Pizza Place    Italian Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 13   Empanada Restaurant           Wings Joint         Hot Dog Joint
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 13      Greek Restaurant   Fried Chicken Joint     French Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 13            Food Court      Food & Drink Shop

# %%
neighborhoods_venues_sorted.loc[neighborhoods_venues_sorted['Neighborhood']=='Parkwoods']
# Out:
#    Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 17    Parkwoods     Food & Drink Shop     Fish & Chips Shop
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 17                  Café  Caribbean Restaurant    Chinese Restaurant
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 17           Pizza Place  Fast Food Restaurant           Wings Joint
#
#           9th Most Common Venue 10th Most Common Venue
# 17  Eastern European Restaurant       Greek Restaurant

# %%
neighborhoods_venues_sorted.loc[neighborhoods_venues_sorted['Neighborhood']=='Victoria Village']
# Out:
#         Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 18  Victoria Village                  Café           Pizza Place
#
#     3rd Most Common Venue 4th Most Common Venue        5th Most Common Venue  \
# 18  Portuguese Restaurant           Wings Joint  Eastern European Restaurant
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 18      Greek Restaurant   Fried Chicken Joint     French Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 18            Food Court      Food & Drink Shop

# %%
neighborhoods_venues_sorted.loc[neighborhoods_venues_sorted['Neighborhood']=='Willowdale West']
# Out:
#        Neighborhood 1st Most Common Venue        2nd Most Common Venue  \
# 20  Willowdale West           Pizza Place  Eastern European Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 20           Wings Joint    Dim Sum Restaurant      Greek Restaurant
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 20   Fried Chicken Joint     French Restaurant            Food Court
#
#    9th Most Common Venue 10th Most Common Venue
# 20     Food & Drink Shop      Fish & Chips Shop

# %%
neighborhoods_venues_sorted.loc[neighborhoods_venues_sorted['Neighborhood']=='York Mills West']
# Out:
#        Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 21  York Mills West            Restaurant     French Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 21           Wings Joint    Dim Sum Restaurant      Greek Restaurant
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 21   Fried Chicken Joint            Food Court     Food & Drink Shop
#
#    9th Most Common Venue 10th Most Common Venue
# 21     Fish & Chips Shop   Fast Food Restaurant
